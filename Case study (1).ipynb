# %%
item_prices={'apple': 10, 'milk': 50}
purchased_items=str(input("Enter the purchased items: "))
quantity=int(input('Enter the quantity of purchased items: '))
if (purchased_items=='apple'):
  total_cost = quantity * 10
  print(f"The cost of the purchased apple is {total_cost}")
elif(purchased_items=='milk'):
  total_cost = quantity * 50
  print(f"The cost of the purchased milk is {total_cost}")
# Out:
# Enter the purchased items: milk
# Enter the quantity of purchased items: 5
# The cost of the purchased milk is 250
